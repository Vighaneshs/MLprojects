# %%
"""
Please upload the data if not already present.
It should be in the same folder as sample_data.
"""

import zipfile
with zipfile.ZipFile("./project2_data.zip", 'r') as zip_ref:
    zip_ref.extractall("./")

# %%
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd
import glob
import os
import re
import itertools

# %%
folder_path = 'all_data'

csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

datasets = {}

pattern = r"c\d+_d\d+"

for file in csv_files:
    filename = os.path.basename(file)
    file_match = re.search(pattern, filename)
    if file_match:
        common_index = file_match.group()

        if common_index not in datasets:
            datasets[common_index] = {}

        df = pd.read_csv(file, header=None)

        if filename.startswith('train'):
            datasets[common_index]['train'] = df
        elif filename.startswith('test'):
            datasets[common_index]['test'] = df
        elif filename.startswith('valid'):
            datasets[common_index]['valid'] = df

# for _, data in datasets.items():
#     if 'train' in data:
#         print(f"Train dataset shape: {data['train'].shape}")
#     if 'test' in data:
#         print(f"Test dataset shape: {data['test'].shape}")
#     if 'valid' in data:
#         print(f"Valid dataset shape: {data['valid'].shape}")

# %%
print(datasets.keys())
# Out:
# dict_keys(['c1000_d100', 'c1000_d1000', 'c1000_d5000', 'c1500_d100', 'c1500_d1000', 'c1500_d5000', 'c1800_d100', 'c1800_d1000', 'c1800_d5000', 'c300_d100', 'c300_d1000', 'c300_d5000', 'c500_d100', 'c500_d1000', 'c500_d5000'])

# %%
from sklearn.tree import DecisionTreeClassifier

for dataset_name in datasets.keys():

  hyper_para_list = [
      ['gini', 'entropy', 'log_loss'], # Criterion
      ['best', 'random'], # Splitter
      [2, 3, 6, 10, None], # max_depth
      [2, 5, 10, 50], # min_samples_split
      [1, 2, 5, 10], # min_samples_leaf
      ['sqrt', 'log2', None], # max_features
  ]

  best_paras = None
  best_accuracy_validation = 0
  for hype_paras in itertools.product(*hyper_para_list):
    tree_model = DecisionTreeClassifier(criterion=hype_paras[0], splitter=hype_paras[1], max_depth=hype_paras[2],
                                        min_samples_split=hype_paras[3], min_samples_leaf=hype_paras[4],
                                        random_state=0, max_features=hype_paras[5])

    X_train, y_train = datasets[dataset_name]['train'].iloc[:,:-1], datasets[dataset_name]['train'].iloc[:,-1]

    tree_model.fit(X_train, y_train)

    y_validpred = tree_model.predict(datasets[dataset_name]['valid'].iloc[:,:-1])

    accuracy = accuracy_score(datasets[dataset_name]['valid'].iloc[:,-1], y_validpred)
    if accuracy > best_accuracy_validation:
      best_accuracy_validation = accuracy
      best_paras = hype_paras

  tuned_tree_model = DecisionTreeClassifier(criterion=best_paras[0], splitter=best_paras[1], max_depth=best_paras[2],
                                        min_samples_split=best_paras[3], min_samples_leaf=best_paras[4],
                                        random_state=0, max_features=best_paras[5])
  combined_data = pd.concat([datasets[dataset_name]['train'], datasets[dataset_name]['valid']], axis=0)
  X_train, y_train = combined_data.iloc[:,:-1], combined_data.iloc[:,-1]
  X_test, y_test = datasets[dataset_name]['test'].iloc[:,:-1], datasets[dataset_name]['test'].iloc[:,-1]

  tuned_tree_model.fit(X_train, y_train)

  y_pred = tuned_tree_model.predict(X_test)

  accuracy = accuracy_score(y_test, y_pred)

  f1 = f1_score(y_test, y_pred, average='binary')

  print("\n\n--------------DECISION TREE CLASSIFIER----------------------")
  print(f"For Dataset - {dataset_name}, best parameter settings found via tuning are :- ")
  print(f"""Criterion - {best_paras[0]}, Splitter - {best_paras[1]},
        Max_Depth - {best_paras[2]}, Min_samples_split - {best_paras[3]},
        Min_samples_leaf - {best_paras[4]}, Max_features - {best_paras[5]}""")
  print(f"Accuracy: {accuracy}")
  print(f"F1 Score: {f1}")
  print("---------------------------------------------------------\n")
# Out:
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c500_d100, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None
# Accuracy: 0.65
# F1 Score: 0.6666666666666666
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c500_d1000, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - random,
#         Max_Depth - 10, Min_samples_split - 50,
#         Min_samples_leaf - 1, Max_features - None
# Accuracy: 0.7155
# F1 Score: 0.6962092899092365
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c1500_d100, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None
# Accuracy: 0.885
# F1 Score: 0.8866995073891626
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c1800_d100, best parameter settings found via tuning are :-
# Criterion - gini, Splitter - best,
#         Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None
# Accuracy: 0.94
# F1 Score: 0.9393939393939394
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c1800_d5000, best parameter settings found via tuning are :-
# Criterion - gini, Splitter - best,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
# Accuracy: 0.9868
# F1 Score: 0.9868499701135685
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c1000_d5000, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
# Accuracy: 0.8587
# F1 Score: 0.8638859454773143
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c1500_d5000, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
# Accuracy: 0.9554
# F1 Score: 0.9557890563045203
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c300_d1000, best parameter settings found via tuning are :-
# Criterion - gini, Splitter - best,
#         Max_Depth - 6, Min_samples_split - 50,
#         Min_samples_leaf - 1, Max_features - None
# Accuracy: 0.6865
# F1 Score: 0.7065980346279832
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c500_d5000, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - random,
#         Max_Depth - 10, Min_samples_split - 50,
#         Min_samples_leaf - 1, Max_features - None
# Accuracy: 0.7844
# F1 Score: 0.7863230921704658
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c1800_d1000, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None
# Accuracy: 0.9725
# F1 Score: 0.9728126544735541
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c1000_d100, best parameter settings found via tuning are :-
# Criterion - gini, Splitter - random,
#         Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
# Accuracy: 0.715
# F1 Score: 0.7135678391959799
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c300_d100, best parameter settings found via tuning are :-
# Criterion - gini, Splitter - random,
#         Max_Depth - 2, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - log2
# Accuracy: 0.48
# F1 Score: 0.5047619047619047
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c1000_d1000, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - random,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
# Accuracy: 0.797
# F1 Score: 0.8059273422562141
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c1500_d1000, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
# Accuracy: 0.9195
# F1 Score: 0.9220338983050848
# ---------------------------------------------------------
#
#
#
# --------------DECISION TREE CLASSIFIER----------------------
# For Dataset - c300_d5000, best parameter settings found via tuning are :-
# Criterion - entropy, Splitter - random,
#         Max_Depth - 10, Min_samples_split - 50,
#         Min_samples_leaf - 1, Max_features - None
# Accuracy: 0.7786
# F1 Score: 0.785797213622291
# ---------------------------------------------------------

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier

for dataset_name in datasets.keys():

  #Based on the previous result, we got the best hyper_parameters for a Decision Tree
  best_dtc_hyper = {
   'c1800_d100':['gini', 'best', 6, 2, 5, None],
   'c1000_d1000':['entropy', 'random', 10, 2, 2, None],
   'c300_d1000':['gini', 'best', 6, 50, 1, None],
   'c1000_d100':['gini', 'random', 6, 2, 2, None],
   'c1800_d5000':['gini', 'best', 10, 2, 2, None],
   'c500_d1000':['entropy', 'random', 10, 50, 1, None],
   'c1800_d1000':['entropy', 'best', 10, 2, 1, None],
   'c1000_d5000':['entropy', 'best', 10, 2, 2, None],
   'c500_d5000':['entropy', 'random', 10, 50, 1, None],
   'c300_d5000':['entropy', 'random', 10, 50, 1, None],
   'c300_d100':['gini', 'random', 2, 2, 1, 'log2'],
   'c500_d100':['entropy', 'best', 6, 2, 5, None],
   'c1500_d100':['entropy', 'best', 6, 2, 5, None],
   'c1500_d1000':['entropy', 'best', 10, 2, 2, None],
   'c1500_d5000':['entropy', 'best', 10, 2, 2, None]
  }

  bc_hyper_para_list = [
      [10, 50, 100], # n_estimators
      [0.5, 1.0], # max_samples
      [0.5, 1.0], # max_features
      [True], # bootstrap
      [False, True], # bootstrap_features
      [False], # oob_score
      [False]  # warm_start
  ]

  best_paras = None
  best_accuracy_validation = 0
  for hype_paras_bagging in itertools.product(*bc_hyper_para_list):
    hype_paras = best_dtc_hyper[dataset_name]
    dc_tree_model = DecisionTreeClassifier(criterion=hype_paras[0], splitter=hype_paras[1], max_depth=hype_paras[2],
                                        min_samples_split=hype_paras[3], min_samples_leaf=hype_paras[4],
                                        random_state=0, max_features=hype_paras[5])

    tree_model = BaggingClassifier(estimator=dc_tree_model, n_estimators=hype_paras_bagging[0], random_state=0,
                                   max_samples=hype_paras_bagging[1], max_features=hype_paras_bagging[2],
                                   bootstrap=hype_paras_bagging[3], bootstrap_features=hype_paras_bagging[4],
                                   oob_score=hype_paras_bagging[5], warm_start=hype_paras_bagging[6])

    X_train, y_train = datasets[dataset_name]['train'].iloc[:,:-1], datasets[dataset_name]['train'].iloc[:,-1]

    tree_model.fit(X_train, y_train)

    y_validpred = tree_model.predict(datasets[dataset_name]['valid'].iloc[:,:-1])

    accuracy = accuracy_score(datasets[dataset_name]['valid'].iloc[:,-1], y_validpred)
    if accuracy > best_accuracy_validation:
      best_accuracy_validation = accuracy
      best_paras = hype_paras_bagging

  hype_paras = best_dtc_hyper[dataset_name]
  dc_tree_model = DecisionTreeClassifier(criterion=hype_paras[0], splitter=hype_paras[1], max_depth=hype_paras[2],
                                        min_samples_split=hype_paras[3], min_samples_leaf=hype_paras[4],
                                        random_state=0, max_features=hype_paras[5])
  hype_paras_bagging = best_paras
  tuned_tree_model = BaggingClassifier(estimator=dc_tree_model, n_estimators=hype_paras_bagging[0], random_state=0,
                                   max_samples=hype_paras_bagging[1], max_features=hype_paras_bagging[2],
                                   bootstrap=hype_paras_bagging[3], bootstrap_features=hype_paras_bagging[4],
                                   oob_score=hype_paras_bagging[5], warm_start=hype_paras_bagging[6])

  combined_data = pd.concat([datasets[dataset_name]['train'], datasets[dataset_name]['valid']], axis=0)
  X_train, y_train = combined_data.iloc[:,:-1], combined_data.iloc[:,-1]
  X_test, y_test = datasets[dataset_name]['test'].iloc[:,:-1], datasets[dataset_name]['test'].iloc[:,-1]

  tuned_tree_model.fit(X_train, y_train)

  y_pred = tuned_tree_model.predict(X_test)

  accuracy = accuracy_score(y_test, y_pred)

  f1 = f1_score(y_test, y_pred, average='binary')

  print("\n\n---------------DECISION TREE WITH BAGGING---------------------------")
  print(f"For Dataset - {dataset_name}, best parameter settings found via tuning for the Decision Tree Classifier are :- ")
  print(f"""Criterion - {hype_paras[0]}, Splitter - {hype_paras[1]},
        Max_Depth - {hype_paras[2]}, Min_samples_split - {hype_paras[3]},
        Min_samples_leaf - {hype_paras[4]}, Max_features - {hype_paras[5]}\n""")

  print(f"For Dataset - {dataset_name}, best parameter settings found via tuning for the Bagging Classifier are :- ")
  print(f"""no of estimators = {best_paras[0]}, max_samples = {best_paras[1]},
            max_features = {best_paras[2]}, bootstrap? = {best_paras[3]},
            bootstrap_features? = {best_paras[4]}, oob_score? = {best_paras[5]},
            warm_start? = {best_paras[6]}""")

  print(f"Accuracy: {accuracy}")
  print(f"F1 Score: {f1}")
  print("---------------------------------------------------------\n")
# Out:
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c500_d100, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None
#
# For Dataset - c500_d100, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 0.5,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = False, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.875
# F1 Score: 0.8792270531400966
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c500_d1000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - random,
#         Max_Depth - 10, Min_samples_split - 50,
#         Min_samples_leaf - 1, Max_features - None
#
# For Dataset - c500_d1000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 1.0,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = True, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.914
# F1 Score: 0.9141716566866267
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c1500_d100, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None
#
# For Dataset - c1500_d100, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 50, max_samples = 0.5,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = False, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.99
# F1 Score: 0.99
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c1800_d100, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - gini, Splitter - best,
#         Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None
#
# For Dataset - c1800_d100, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 50, max_samples = 0.5,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = False, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.995
# F1 Score: 0.9949748743718593
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c1800_d5000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - gini, Splitter - best,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
#
# For Dataset - c1800_d5000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 50, max_samples = 1.0,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = True, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.9998
# F1 Score: 0.9998000399920016
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c1000_d5000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
#
# For Dataset - c1000_d5000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 0.5,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = True, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.989
# F1 Score: 0.9890329012961117
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c1500_d5000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
#
# For Dataset - c1500_d5000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 0.5,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = True, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.9993
# F1 Score: 0.9992999299929993
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c300_d1000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - gini, Splitter - best,
#         Max_Depth - 6, Min_samples_split - 50,
#         Min_samples_leaf - 1, Max_features - None
#
# For Dataset - c300_d1000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 1.0,
#             max_features = 1.0, bootstrap? = True,
#             bootstrap_features? = False, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.858
# F1 Score: 0.8633301251203079
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c500_d5000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - random,
#         Max_Depth - 10, Min_samples_split - 50,
#         Min_samples_leaf - 1, Max_features - None
#
# For Dataset - c500_d5000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 50, max_samples = 1.0,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = False, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.9493
# F1 Score: 0.9496474327142715
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c1800_d1000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None
#
# For Dataset - c1800_d1000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 50, max_samples = 0.5,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = True, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.9995
# F1 Score: 0.9995002498750625
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c1000_d100, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - gini, Splitter - random,
#         Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
#
# For Dataset - c1000_d100, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 1.0,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = True, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.95
# F1 Score: 0.95
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c300_d100, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - gini, Splitter - random,
#         Max_Depth - 2, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - log2
#
# For Dataset - c300_d100, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 1.0,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = False, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.755
# F1 Score: 0.7537688442211056
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c1000_d1000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - random,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
#
# For Dataset - c1000_d1000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 0.5,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = True, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.984
# F1 Score: 0.9841269841269841
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c1500_d1000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - best,
#         Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None
#
# For Dataset - c1500_d1000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 0.5,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = True, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.9975
# F1 Score: 0.9974962443665498
# ---------------------------------------------------------
#
#
#
# ---------------DECISION TREE WITH BAGGING---------------------------
# For Dataset - c300_d5000, best parameter settings found via tuning for the Decision Tree Classifier are :-
# Criterion - entropy, Splitter - random,
#         Max_Depth - 10, Min_samples_split - 50,
#         Min_samples_leaf - 1, Max_features - None
#
# For Dataset - c300_d5000, best parameter settings found via tuning for the Bagging Classifier are :-
# no of estimators = 100, max_samples = 1.0,
#             max_features = 0.5, bootstrap? = True,
#             bootstrap_features? = False, oob_score? = False,
#             warm_start? = False
# Accuracy: 0.9402
# F1 Score: 0.9417721518987342
# ---------------------------------------------------------

# %%
from sklearn.ensemble import RandomForestClassifier

for dataset_name in datasets.keys():

  hyper_para_list = [
      ['gini', 'entropy', 'log_loss'], # Criterion
      [0], # verbose
      [2, 6, 10], # max_depth
      [2, 10], # min_samples_split
      [1, 2, 5], # min_samples_leaf
      [None], # max_features
      [50, 100], # n_estimators
  ]

  best_paras = None
  best_accuracy_validation = 0
  for hype_paras in itertools.product(*hyper_para_list):
    tree_model = RandomForestClassifier(n_jobs=-1, criterion=hype_paras[0], max_depth=hype_paras[2],
                                        min_samples_split=hype_paras[3], min_samples_leaf=hype_paras[4],
                                        random_state=0, max_features=hype_paras[5], n_estimators=hype_paras[6], verbose=hype_paras[1])

    X_train, y_train = datasets[dataset_name]['train'].iloc[:,:-1], datasets[dataset_name]['train'].iloc[:,-1]

    tree_model.fit(X_train, y_train)

    y_validpred = tree_model.predict(datasets[dataset_name]['valid'].iloc[:,:-1])

    accuracy = accuracy_score(datasets[dataset_name]['valid'].iloc[:,-1], y_validpred)
    if accuracy > best_accuracy_validation:
      best_accuracy_validation = accuracy
      best_paras = hype_paras

  tuned_tree_model = RandomForestClassifier(n_jobs=-1, criterion=best_paras[0], max_depth=best_paras[2],
                                        min_samples_split=best_paras[3], min_samples_leaf=best_paras[4],
                                        random_state=0, max_features=best_paras[5], n_estimators=best_paras[6], verbose=best_paras[1])
  combined_data = pd.concat([datasets[dataset_name]['train'], datasets[dataset_name]['valid']], axis=0)
  X_train, y_train = combined_data.iloc[:,:-1], combined_data.iloc[:,-1]
  X_test, y_test = datasets[dataset_name]['test'].iloc[:,:-1], datasets[dataset_name]['test'].iloc[:,-1]

  tuned_tree_model.fit(X_train, y_train)

  y_pred = tuned_tree_model.predict(X_test)

  accuracy = accuracy_score(y_test, y_pred)

  f1 = f1_score(y_test, y_pred, average='binary')

  print("\n\n--------------RANDOM FOREST CLASSIFIER----------------------")
  print(f"For Dataset - {dataset_name}, best parameter settings found via tuning are :- ")
  print(f"""Criterion - {best_paras[0]}, Max_Depth - {best_paras[2]}, Min_samples_split - {best_paras[3]},
        Min_samples_leaf - {best_paras[4]}, Max_features - {best_paras[5]},
        n_estimators - {best_paras[6]}""")
  print(f"Accuracy: {accuracy}")
  print(f"F1 Score: {f1}")
  print("---------------------------------------------------------\n")
# Out:
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c1000_d100, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.89
# F1 Score: 0.8888888888888888
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c1000_d1000, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 10,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.948
# F1 Score: 0.9481037924151696
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c1000_d5000, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.9515
# F1 Score: 0.9520893015904376
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c1500_d100, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 6, Min_samples_split - 10,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.98
# F1 Score: 0.98
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c1500_d1000, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.9835
# F1 Score: 0.9835082458770614
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c1500_d5000, best parameter settings found via tuning are :-
# Criterion - entropy, Max_Depth - 10, Min_samples_split - 10,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.9879
# F1 Score: 0.9879229464018365
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c1800_d100, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 50
# Accuracy: 0.97
# F1 Score: 0.9696969696969697
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c1800_d1000, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 50
# Accuracy: 0.9925
# F1 Score: 0.9924887330996495
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c1800_d5000, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 10,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.996
# F1 Score: 0.995999199839968
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c300_d100, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.82
# F1 Score: 0.8269230769230769
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c300_d1000, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.8845
# F1 Score: 0.8873720136518771
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c300_d5000, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 10,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.9036
# F1 Score: 0.9107076695072249
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c500_d100, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 50
# Accuracy: 0.82
# F1 Score: 0.8301886792452831
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c500_d1000, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.8885
# F1 Score: 0.8883324987481221
# ---------------------------------------------------------
#
#
#
# --------------RANDOM FOREST CLASSIFIER----------------------
# For Dataset - c500_d5000, best parameter settings found via tuning are :-
# Criterion - gini, Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100
# Accuracy: 0.932
# F1 Score: 0.9339677607302389
# ---------------------------------------------------------

# %%
from sklearn.ensemble import GradientBoostingClassifier

for dataset_name in datasets.keys():

  hyper_para_list = [
      ['exponential', 'log_loss'], # loss
      [0.1], # learning_rate
      [2, 6, 10], # max_depth
      [2, 10], # min_samples_split
      [1, 2, 5], # min_samples_leaf
      [None], # max_features
      [50, 100], # n_estimators
      [0.5, 1.0], # subsample
      ['friedman_mse', 'squared_error'], # criterion
  ]

  best_paras = None
  best_accuracy_validation = 0
  for hype_paras in itertools.product(*hyper_para_list):
    tree_model = GradientBoostingClassifier(loss=hype_paras[0], learning_rate=hype_paras[1], max_depth=hype_paras[2],
                                        min_samples_split=hype_paras[3], min_samples_leaf=hype_paras[4],
                                        random_state=0, max_features=hype_paras[5], n_estimators=hype_paras[6], subsample=hype_paras[7], criterion=hype_paras[8], verbose=0)

    X_train, y_train = datasets[dataset_name]['train'].iloc[:,:-1], datasets[dataset_name]['train'].iloc[:,-1]

    tree_model.fit(X_train, y_train)

    y_validpred = tree_model.predict(datasets[dataset_name]['valid'].iloc[:,:-1])

    accuracy = accuracy_score(datasets[dataset_name]['valid'].iloc[:,-1], y_validpred)
    if accuracy > best_accuracy_validation:
      best_accuracy_validation = accuracy
      best_paras = hype_paras

  tuned_tree_model = GradientBoostingClassifier(loss=best_paras[0], learning_rate=best_paras[1], max_depth=best_paras[2],
                                        min_samples_split=best_paras[3], min_samples_leaf=best_paras[4],
                                        random_state=0, max_features=best_paras[5], n_estimators=best_paras[6], subsample=best_paras[7], criterion=best_paras[8], verbose=0)


  combined_data = pd.concat([datasets[dataset_name]['train'], datasets[dataset_name]['valid']], axis=0)
  X_train, y_train = combined_data.iloc[:,:-1], combined_data.iloc[:,-1]
  X_test, y_test = datasets[dataset_name]['test'].iloc[:,:-1], datasets[dataset_name]['test'].iloc[:,-1]

  tuned_tree_model.fit(X_train, y_train)

  y_pred = tuned_tree_model.predict(X_test)

  accuracy = accuracy_score(y_test, y_pred)

  f1 = f1_score(y_test, y_pred, average='binary')



  print("\n\n--------------GRADIENT BOOSTING CLASSIFIER----------------------")
  print(f"For Dataset - {dataset_name}, best parameter settings found via tuning are :- ")
  print(f"""Loss - {best_paras[0]}, Learning Rate - {best_paras[1]}
        Criterion - {best_paras[8]}, Max_Depth - {best_paras[2]}, Min_samples_split - {best_paras[3]},
        Min_samples_leaf - {best_paras[4]}, Max_features - {best_paras[5]},
        n_estimators - {best_paras[6]}, subsample - {best_paras[7]}""")
  print(f"Accuracy: {accuracy}")
  print(f"F1 Score: {f1}")
  print("---------------------------------------------------------\n")
# Out:
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c1000_d100, best parameter settings found via tuning are :-
# Loss - exponential, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 10, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 0.975
# F1 Score: 0.9751243781094527
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c1000_d1000, best parameter settings found via tuning are :-
# Loss - exponential, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 10, Min_samples_split - 10,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 0.9915
# F1 Score: 0.9915127309036446
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c1000_d5000, best parameter settings found via tuning are :-
# Loss - exponential, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 0.9998
# F1 Score: 0.9998000399920016
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c1500_d100, best parameter settings found via tuning are :-
# Loss - exponential, Learning Rate - 0.1
#         Criterion - squared_error, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 1.0
# F1 Score: 1.0
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c1500_d1000, best parameter settings found via tuning are :-
# Loss - exponential, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 2, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 0.997
# F1 Score: 0.997
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c1500_d5000, best parameter settings found via tuning are :-
# Loss - log_loss, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 1.0
# F1 Score: 1.0
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c1800_d100, best parameter settings found via tuning are :-
# Loss - exponential, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 2, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 50, subsample - 0.5
# Accuracy: 0.995
# F1 Score: 0.9950248756218906
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c1800_d1000, best parameter settings found via tuning are :-
# Loss - exponential, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 2, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 1.0
# F1 Score: 1.0
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c1800_d5000, best parameter settings found via tuning are :-
# Loss - exponential, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 2, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 0.9998
# F1 Score: 0.9998000399920016
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c300_d100, best parameter settings found via tuning are :-
# Loss - exponential, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 6, Min_samples_split - 10,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 0.79
# F1 Score: 0.7980769230769231
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c300_d1000, best parameter settings found via tuning are :-
# Loss - log_loss, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None,
#         n_estimators - 100, subsample - 1.0
# Accuracy: 0.9845
# F1 Score: 0.9847215377033022
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c300_d5000, best parameter settings found via tuning are :-
# Loss - log_loss, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100, subsample - 1.0
# Accuracy: 0.9984
# F1 Score: 0.9984025559105432
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c500_d100, best parameter settings found via tuning are :-
# Loss - log_loss, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 6, Min_samples_split - 10,
#         Min_samples_leaf - 2, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 0.885
# F1 Score: 0.883248730964467
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c500_d1000, best parameter settings found via tuning are :-
# Loss - log_loss, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 5, Max_features - None,
#         n_estimators - 100, subsample - 0.5
# Accuracy: 0.9875
# F1 Score: 0.987629886194953
# ---------------------------------------------------------
#
#
#
# --------------GRADIENT BOOSTING CLASSIFIER----------------------
# For Dataset - c500_d5000, best parameter settings found via tuning are :-
# Loss - log_loss, Learning Rate - 0.1
#         Criterion - friedman_mse, Max_Depth - 6, Min_samples_split - 2,
#         Min_samples_leaf - 1, Max_features - None,
#         n_estimators - 100, subsample - 1.0
# Accuracy: 0.9985
# F1 Score: 0.9985022466300549
# ---------------------------------------------------------

# %%
"""
MINST 
"""
from sklearn.datasets import fetch_openml
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
X = X / 255.

X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
#chosing the hyper-parameters which were chosen as the best on average for previous DecisionTree Model

dect = DecisionTreeClassifier()

params = {
    'max_depth': randint(3, 10),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 10),
    'criterion': ['gini'],
    'max_features':['sqrt', 'log2', None]
}

rand_s = RandomizedSearchCV(
    estimator=dect,
    param_distributions=params,
    n_iter=100,
    cv=5,
    verbose=3,
    random_state=0
)

rand_s.fit(X_train, y_train)

best_model = rand_s.best_estimator_
test_score = best_model.score(X_test, y_test)

print("\n\n--------------DECISION TREE CLASSIFIER On MNIST----------------------")
print(f"Accuracy: {test_score}")
print("---------------------------------------------------------\n")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END criterion=gini, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.607 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.584 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.567 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.586 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.624 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.554 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.517 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.568 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.540 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.568 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=8;, score=0.552 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=8;, score=0.539 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=8;, score=0.569 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=8;, score=0.572 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=8;, score=0.569 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=8;, score=0.386 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=8;, score=0.401 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=8;, score=0.360 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=8;, score=0.360 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=8;, score=0.416 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=2, min_samples_split=7;, score=0.764 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=2, min_samples_split=7;, score=0.750 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=2, min_samples_split=7;, score=0.765 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=2, min_samples_split=7;, score=0.750 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=2, min_samples_split=7;, score=0.784 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=9, min_samples_split=3;, score=0.433 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=9, min_samples_split=3;, score=0.429 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=9, min_samples_split=3;, score=0.410 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=9, min_samples_split=3;, score=0.462 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=9, min_samples_split=3;, score=0.371 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=7;, score=0.708 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=7;, score=0.682 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=7;, score=0.681 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=7;, score=0.699 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=7;, score=0.636 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=5;, score=0.738 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=5;, score=0.749 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=5;, score=0.753 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=5;, score=0.768 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=5;, score=0.763 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.332 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.367 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.341 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.338 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=7;, score=0.381 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=8, min_samples_split=2;, score=0.738 total time=   5.1s
# [CV 2/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=8, min_samples_split=2;, score=0.718 total time=   4.7s
# [CV 3/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=8, min_samples_split=2;, score=0.731 total time=   5.0s
# [CV 4/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=8, min_samples_split=2;, score=0.716 total time=   5.7s
# [CV 5/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=8, min_samples_split=2;, score=0.757 total time=   8.3s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=9;, score=0.461 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=9;, score=0.436 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=9;, score=0.428 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=9;, score=0.438 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=9;, score=0.456 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.626 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.576 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.573 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.567 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.610 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=9, max_features=None, min_samples_leaf=8, min_samples_split=6;, score=0.832 total time=  11.9s
# [CV 2/5] END criterion=gini, max_depth=9, max_features=None, min_samples_leaf=8, min_samples_split=6;, score=0.832 total time=  11.8s
# [CV 3/5] END criterion=gini, max_depth=9, max_features=None, min_samples_leaf=8, min_samples_split=6;, score=0.830 total time=  11.9s
# [CV 4/5] END criterion=gini, max_depth=9, max_features=None, min_samples_leaf=8, min_samples_split=6;, score=0.825 total time=  12.1s
# [CV 5/5] END criterion=gini, max_depth=9, max_features=None, min_samples_leaf=8, min_samples_split=6;, score=0.844 total time=  12.1s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split
# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

#chosing the hyper-parameters which were chosen as the best on average for previous Bagging with DecisionTree Model

decisTree = DecisionTreeClassifier()

bg_clf = BaggingClassifier(estimator=decisTree)

param = {
    'estimator__max_depth': randint(3, 10),
    'estimator__min_samples_split': randint(2, 10),
    'estimator__min_samples_leaf': randint(1, 10),
    'estimator__criterion': ['gini'],
    'estimator__max_features':['sqrt', 'log2'],
    'n_estimators': randint(10, 200),
    'max_samples': randint(1, 1000),
    'max_features': randint(1, 1000),
    'bootstrap': [True, False],
    'bootstrap_features': [True, False]
}

rand_s = RandomizedSearchCV(
    estimator=bg_clf,
    param_distributions=param,
    n_iter=100,
    cv=5,
    verbose=3,
    random_state=0
)

rand_s.fit(X_train, y_train)

best_model = rand_s.best_estimator_
test_score = best_model.score(X_test, y_test)

print("\n\n--------------DECISION TREE CLASSIFIER with Bagging On MNIST----------------------")
print(f"Accuracy: {test_score}")
print("---------------------------------------------------------\n")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, max_features=708, max_samples=360, n_estimators=19;, score=0.834 total time=   3.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, max_features=708, max_samples=360, n_estimators=19;, score=0.820 total time=   2.9s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, max_features=708, max_samples=360, n_estimators=19;, score=0.808 total time=   2.9s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, max_features=708, max_samples=360, n_estimators=19;, score=0.825 total time=   3.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, max_features=708, max_samples=360, n_estimators=19;, score=0.835 total time=   2.9s
# [CV 1/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=473, max_samples=601, n_estimators=150;, score=0.858 total time=  15.7s
# [CV 2/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=473, max_samples=601, n_estimators=150;, score=0.839 total time=  15.7s
# [CV 3/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=473, max_samples=601, n_estimators=150;, score=0.836 total time=  15.7s
# [CV 4/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=473, max_samples=601, n_estimators=150;, score=0.843 total time=  15.7s
# [CV 5/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=473, max_samples=601, n_estimators=150;, score=0.871 total time=  15.7s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=601, max_samples=850, n_estimators=175;, score=0.885 total time=  23.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=601, max_samples=850, n_estimators=175;, score=0.873 total time=  23.1s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=601, max_samples=850, n_estimators=175;, score=0.875 total time=  23.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=601, max_samples=850, n_estimators=175;, score=0.880 total time=  23.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=8, max_features=601, max_samples=850, n_estimators=175;, score=0.897 total time=  23.1s
# [CV 1/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=977, max_samples=756, n_estimators=89;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=977, max_samples=756, n_estimators=89;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=977, max_samples=756, n_estimators=89;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=977, max_samples=756, n_estimators=89;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=977, max_samples=756, n_estimators=89;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=756, max_samples=798, n_estimators=157;, score=0.848 total time=  25.7s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=756, max_samples=798, n_estimators=157;, score=0.836 total time=  25.7s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=756, max_samples=798, n_estimators=157;, score=0.831 total time=  25.9s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=756, max_samples=798, n_estimators=157;, score=0.838 total time=  25.9s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=756, max_samples=798, n_estimators=157;, score=0.856 total time=  25.9s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=715, max_samples=245, n_estimators=161;, score=0.759 total time=  25.0s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=715, max_samples=245, n_estimators=161;, score=0.751 total time=  24.8s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=715, max_samples=245, n_estimators=161;, score=0.755 total time=  24.9s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=715, max_samples=245, n_estimators=161;, score=0.756 total time=  24.9s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=715, max_samples=245, n_estimators=161;, score=0.786 total time=  24.8s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=803, max_samples=129, n_estimators=138;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=803, max_samples=129, n_estimators=138;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=803, max_samples=129, n_estimators=138;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=803, max_samples=129, n_estimators=138;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=803, max_samples=129, n_estimators=138;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=274, max_samples=336, n_estimators=142;, score=0.846 total time=   8.8s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=274, max_samples=336, n_estimators=142;, score=0.842 total time=   8.9s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=274, max_samples=336, n_estimators=142;, score=0.830 total time=   8.8s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=274, max_samples=336, n_estimators=142;, score=0.838 total time=   8.9s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=274, max_samples=336, n_estimators=142;, score=0.863 total time=   9.0s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=322, max_samples=938, n_estimators=67;, score=0.827 total time=   5.0s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=322, max_samples=938, n_estimators=67;, score=0.819 total time=   5.0s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=322, max_samples=938, n_estimators=67;, score=0.822 total time=   5.0s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=322, max_samples=938, n_estimators=67;, score=0.827 total time=   5.0s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=3, max_features=322, max_samples=938, n_estimators=67;, score=0.856 total time=   5.0s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=897, max_samples=399, n_estimators=109;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=897, max_samples=399, n_estimators=109;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=897, max_samples=399, n_estimators=109;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=897, max_samples=399, n_estimators=109;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=897, max_samples=399, n_estimators=109;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=325, max_samples=775, n_estimators=57;, score=0.819 total time=   4.3s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=325, max_samples=775, n_estimators=57;, score=0.805 total time=   4.3s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=325, max_samples=775, n_estimators=57;, score=0.801 total time=   4.3s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=325, max_samples=775, n_estimators=57;, score=0.813 total time=   4.3s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=5, max_features=325, max_samples=775, n_estimators=57;, score=0.813 total time=   4.3s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=6, max_features=847, max_samples=144, n_estimators=158;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=6, max_features=847, max_samples=144, n_estimators=158;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=6, max_features=847, max_samples=144, n_estimators=158;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=6, max_features=847, max_samples=144, n_estimators=158;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=6, max_features=847, max_samples=144, n_estimators=158;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=2, max_features=306, max_samples=582, n_estimators=179;, score=0.877 total time=  12.8s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=2, max_features=306, max_samples=582, n_estimators=179;, score=0.865 total time=  12.7s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=2, max_features=306, max_samples=582, n_estimators=179;, score=0.861 total time=  12.7s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=2, max_features=306, max_samples=582, n_estimators=179;, score=0.872 total time=  12.7s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=2, max_features=306, max_samples=582, n_estimators=179;, score=0.883 total time=  12.7s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=3, max_features=691, max_samples=293, n_estimators=172;, score=0.890 total time=  25.8s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=3, max_features=691, max_samples=293, n_estimators=172;, score=0.879 total time=  26.0s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=3, max_features=691, max_samples=293, n_estimators=172;, score=0.873 total time=  25.8s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=3, max_features=691, max_samples=293, n_estimators=172;, score=0.883 total time=  26.0s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=3, max_features=691, max_samples=293, n_estimators=172;, score=0.898 total time=  26.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=918, max_samples=202, n_estimators=137;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=918, max_samples=202, n_estimators=137;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=918, max_samples=202, n_estimators=137;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=918, max_samples=202, n_estimators=137;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=9, max_features=918, max_samples=202, n_estimators=137;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=131, max_samples=378, n_estimators=108;, score=0.815 total time=   3.5s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=131, max_samples=378, n_estimators=108;, score=0.807 total time=   3.5s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=131, max_samples=378, n_estimators=108;, score=0.810 total time=   3.5s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=131, max_samples=378, n_estimators=108;, score=0.817 total time=   3.5s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=131, max_samples=378, n_estimators=108;, score=0.834 total time=   3.5s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=943, max_samples=740, n_estimators=158;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=943, max_samples=740, n_estimators=158;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=943, max_samples=740, n_estimators=158;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=943, max_samples=740, n_estimators=158;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=943, max_samples=740, n_estimators=158;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=6, max_features=779, max_samples=87, n_estimators=53;, score=0.805 total time=   9.0s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=6, max_features=779, max_samples=87, n_estimators=53;, score=0.784 total time=   9.0s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=6, max_features=779, max_samples=87, n_estimators=53;, score=0.768 total time=   9.0s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=6, max_features=779, max_samples=87, n_estimators=53;, score=0.787 total time=   9.0s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=6, max_features=779, max_samples=87, n_estimators=53;, score=0.809 total time=   8.9s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, max_features=183, max_samples=129, n_estimators=48;, score=0.755 total time=   2.1s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, max_features=183, max_samples=129, n_estimators=48;, score=0.762 total time=   2.1s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, max_features=183, max_samples=129, n_estimators=48;, score=0.739 total time=   2.1s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, max_features=183, max_samples=129, n_estimators=48;, score=0.767 total time=   2.1s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, max_features=183, max_samples=129, n_estimators=48;, score=0.768 total time=   2.1s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=489, max_samples=590, n_estimators=40;, score=0.818 total time=   4.4s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=489, max_samples=590, n_estimators=40;, score=0.798 total time=   4.4s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=489, max_samples=590, n_estimators=40;, score=0.791 total time=   4.4s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=489, max_samples=590, n_estimators=40;, score=0.808 total time=   4.4s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=6, max_features=489, max_samples=590, n_estimators=40;, score=0.827 total time=   4.3s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=270, max_samples=881, n_estimators=50;, score=0.820 total time=   3.1s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=270, max_samples=881, n_estimators=50;, score=0.820 total time=   3.1s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=270, max_samples=881, n_estimators=50;, score=0.828 total time=   3.1s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=270, max_samples=881, n_estimators=50;, score=0.823 total time=   3.1s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=270, max_samples=881, n_estimators=50;, score=0.848 total time=   3.1s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=2, max_features=181, max_samples=324, n_estimators=71;, score=0.747 total time=   3.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=2, max_features=181, max_samples=324, n_estimators=71;, score=0.746 total time=   3.0s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=2, max_features=181, max_samples=324, n_estimators=71;, score=0.738 total time=   3.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=2, max_features=181, max_samples=324, n_estimators=71;, score=0.726 total time=   3.1s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=2, max_features=181, max_samples=324, n_estimators=71;, score=0.767 total time=   3.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=7, max_features=890, max_samples=622, n_estimators=85;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=7, max_features=890, max_samples=622, n_estimators=85;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=7, max_features=890, max_samples=622, n_estimators=85;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=7, max_features=890, max_samples=622, n_estimators=85;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=7, max_features=890, max_samples=622, n_estimators=85;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=8, max_features=26, max_samples=465, n_estimators=198;, score=0.740 total time=   1.9s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=8, max_features=26, max_samples=465, n_estimators=198;, score=0.755 total time=   1.9s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=8, max_features=26, max_samples=465, n_estimators=198;, score=0.752 total time=   2.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=8, max_features=26, max_samples=465, n_estimators=198;, score=0.749 total time=   2.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=8, max_features=26, max_samples=465, n_estimators=198;, score=0.763 total time=   1.9s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=3, max_features=873, max_samples=929, n_estimators=131;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=3, max_features=873, max_samples=929, n_estimators=131;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=3, max_features=873, max_samples=929, n_estimators=131;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=3, max_features=873, max_samples=929, n_estimators=131;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=3, max_features=873, max_samples=929, n_estimators=131;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=2, max_features=592, max_samples=42, n_estimators=28;, score=0.553 total time=   3.6s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=2, max_features=592, max_samples=42, n_estimators=28;, score=0.463 total time=   3.6s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=2, max_features=592, max_samples=42, n_estimators=28;, score=0.571 total time=   3.6s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=2, max_features=592, max_samples=42, n_estimators=28;, score=0.555 total time=   3.6s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=9, estimator__min_samples_split=2, max_features=592, max_samples=42, n_estimators=28;, score=0.552 total time=   3.6s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=9, max_features=887, max_samples=813, n_estimators=135;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=9, max_features=887, max_samples=813, n_estimators=135;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=9, max_features=887, max_samples=813, n_estimators=135;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=9, max_features=887, max_samples=813, n_estimators=135;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=9, max_features=887, max_samples=813, n_estimators=135;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=717, max_samples=999, n_estimators=45;, score=0.830 total time=   7.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=717, max_samples=999, n_estimators=45;, score=0.816 total time=   7.0s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=717, max_samples=999, n_estimators=45;, score=0.824 total time=   7.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=717, max_samples=999, n_estimators=45;, score=0.830 total time=   6.9s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=4, max_features=717, max_samples=999, n_estimators=45;, score=0.843 total time=   7.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=33, max_samples=12, n_estimators=114;, score=0.104 total time=   1.3s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=33, max_samples=12, n_estimators=114;, score=0.099 total time=   1.3s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=33, max_samples=12, n_estimators=114;, score=0.112 total time=   1.3s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=33, max_samples=12, n_estimators=114;, score=0.099 total time=   1.3s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=33, max_samples=12, n_estimators=114;, score=0.097 total time=   1.2s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=7, max_features=669, max_samples=624, n_estimators=12;, score=0.812 total time=   1.8s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=7, max_features=669, max_samples=624, n_estimators=12;, score=0.793 total time=   1.7s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=7, max_features=669, max_samples=624, n_estimators=12;, score=0.779 total time=   1.8s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=7, max_features=669, max_samples=624, n_estimators=12;, score=0.803 total time=   1.8s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=9, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=7, max_features=669, max_samples=624, n_estimators=12;, score=0.817 total time=   1.8s
# [CV 1/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=5, max_features=175, max_samples=149, n_estimators=191;, score=0.773 total time=   7.8s
# [CV 2/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=5, max_features=175, max_samples=149, n_estimators=191;, score=0.775 total time=   7.9s
# [CV 3/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=5, max_features=175, max_samples=149, n_estimators=191;, score=0.774 total time=   7.9s
# [CV 4/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=5, max_features=175, max_samples=149, n_estimators=191;, score=0.781 total time=   7.9s
# [CV 5/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=5, max_features=175, max_samples=149, n_estimators=191;, score=0.798 total time=   8.0s
# [CV 1/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=815, max_samples=731, n_estimators=188;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=815, max_samples=731, n_estimators=188;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=815, max_samples=731, n_estimators=188;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=815, max_samples=731, n_estimators=188;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=5, max_features=815, max_samples=731, n_estimators=188;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=9, max_features=62, max_samples=342, n_estimators=107;, score=0.791 total time=   1.9s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=9, max_features=62, max_samples=342, n_estimators=107;, score=0.784 total time=   1.9s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=9, max_features=62, max_samples=342, n_estimators=107;, score=0.779 total time=   1.9s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=9, max_features=62, max_samples=342, n_estimators=107;, score=0.785 total time=   1.9s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=9, max_features=62, max_samples=342, n_estimators=107;, score=0.809 total time=   1.9s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=7, max_features=233, max_samples=768, n_estimators=46;, score=0.838 total time=   2.5s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=7, max_features=233, max_samples=768, n_estimators=46;, score=0.828 total time=   2.5s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=7, max_features=233, max_samples=768, n_estimators=46;, score=0.825 total time=   2.6s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=7, max_features=233, max_samples=768, n_estimators=46;, score=0.840 total time=   2.5s
# ...
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, max_features=644, max_samples=49, n_estimators=86;, score=0.737 total time=  12.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, max_features=644, max_samples=49, n_estimators=86;, score=0.713 total time=  11.9s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, max_features=644, max_samples=49, n_estimators=86;, score=0.714 total time=  12.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, max_features=644, max_samples=49, n_estimators=86;, score=0.707 total time=  12.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, max_features=644, max_samples=49, n_estimators=86;, score=0.750 total time=  12.0s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=562, max_samples=72, n_estimators=100;, score=0.783 total time=  12.3s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=562, max_samples=72, n_estimators=100;, score=0.788 total time=  12.3s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=562, max_samples=72, n_estimators=100;, score=0.771 total time=  12.2s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=562, max_samples=72, n_estimators=100;, score=0.791 total time=  12.2s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=5, max_features=562, max_samples=72, n_estimators=100;, score=0.801 total time=  12.2s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=4, max_features=322, max_samples=888, n_estimators=30;, score=0.858 total time=   2.3s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=4, max_features=322, max_samples=888, n_estimators=30;, score=0.851 total time=   2.3s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=4, max_features=322, max_samples=888, n_estimators=30;, score=0.857 total time=   2.3s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=4, max_features=322, max_samples=888, n_estimators=30;, score=0.843 total time=   2.3s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=8, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=4, max_features=322, max_samples=888, n_estimators=30;, score=0.873 total time=   2.2s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=305, max_samples=963, n_estimators=112;, score=0.856 total time=   7.8s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=305, max_samples=963, n_estimators=112;, score=0.848 total time=   7.9s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=305, max_samples=963, n_estimators=112;, score=0.847 total time=   7.9s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=305, max_samples=963, n_estimators=112;, score=0.846 total time=   7.9s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=6, max_features=305, max_samples=963, n_estimators=112;, score=0.870 total time=   7.9s
# [CV 1/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=6, max_features=91, max_samples=69, n_estimators=115;, score=0.744 total time=   2.7s
# [CV 2/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=6, max_features=91, max_samples=69, n_estimators=115;, score=0.709 total time=   2.7s
# [CV 3/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=6, max_features=91, max_samples=69, n_estimators=115;, score=0.728 total time=   2.7s
# [CV 4/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=6, max_features=91, max_samples=69, n_estimators=115;, score=0.729 total time=   2.8s
# [CV 5/5] END bootstrap=False, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=6, max_features=91, max_samples=69, n_estimators=115;, score=0.754 total time=   2.7s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=9, max_features=929, max_samples=379, n_estimators=43;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=9, max_features=929, max_samples=379, n_estimators=43;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=9, max_features=929, max_samples=379, n_estimators=43;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=9, max_features=929, max_samples=379, n_estimators=43;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=6, estimator__min_samples_split=9, max_features=929, max_samples=379, n_estimators=43;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=4, max_features=789, max_samples=735, n_estimators=166;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=4, max_features=789, max_samples=735, n_estimators=166;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=4, max_features=789, max_samples=735, n_estimators=166;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=4, max_features=789, max_samples=735, n_estimators=166;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=9, estimator__min_samples_split=4, max_features=789, max_samples=735, n_estimators=166;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=4, max_features=636, max_samples=285, n_estimators=162;, score=0.825 total time=  22.5s
# [CV 2/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=4, max_features=636, max_samples=285, n_estimators=162;, score=0.811 total time=  22.4s
# [CV 3/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=4, max_features=636, max_samples=285, n_estimators=162;, score=0.798 total time=  22.5s
# [CV 4/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=4, max_features=636, max_samples=285, n_estimators=162;, score=0.811 total time=  22.5s
# [CV 5/5] END bootstrap=True, bootstrap_features=True, estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=8, estimator__min_samples_split=4, max_features=636, max_samples=285, n_estimators=162;, score=0.835 total time=  22.5s
# [CV 1/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=2, max_features=139, max_samples=708, n_estimators=144;, score=0.869 total time=   4.9s
# [CV 2/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=2, max_features=139, max_samples=708, n_estimators=144;, score=0.857 total time=   4.9s
# [CV 3/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=2, max_features=139, max_samples=708, n_estimators=144;, score=0.854 total time=   5.0s
# [CV 4/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=2, max_features=139, max_samples=708, n_estimators=144;, score=0.862 total time=   5.0s
# [CV 5/5] END bootstrap=True, bootstrap_features=False, estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=7, estimator__min_samples_split=2, max_features=139, max_samples=708, n_estimators=144;, score=0.877 total time=   5.0s
# c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 170 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 170 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py", line 66, in inner_f
#     return f(*args, **kwargs)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_bagging.py", line 402, in fit
#     return self._fit(X, y, max_samples=self.max_samples, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_bagging.py", line 493, in _fit
#     raise ValueError("max_features must be <= n_features")
# ValueError: max_features must be <= n_features
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.82425    0.84933333 0.88181667        nan 0.8419     0.7615
#         nan 0.844      0.82998333        nan 0.81026667        nan
#  0.8716     0.88458333        nan 0.81665           nan 0.7907
#  0.7581     0.80826667 0.8277     0.74496667        nan 0.75173333
#         nan 0.5387            nan 0.82861667 0.10255    0.80095
#  0.78018333        nan 0.78973333 0.83708333 0.82328333 0.80453333
#         nan 0.73926667 0.87795           nan        nan 0.596
#  0.76003333 0.88726667        nan 0.84906667 0.7655     0.86816667
#         nan        nan 0.82338333 0.7956            nan        nan
#  0.82665    0.81826667        nan 0.82068333        nan 0.87266667
#         nan 0.86253333 0.86081667 0.89876667        nan 0.87286667
#         nan 0.73373333 0.88226667 0.82346667        nan 0.87725
#  0.87841667 0.87373333 0.8173            nan 0.83193333        nan
#  0.82416667 0.87298333 0.87713333        nan 0.5455            nan
#         nan 0.85826667        nan 0.8741            nan        nan
#  0.87346667 0.72428333 0.78685    0.85621667 0.8532     0.7327
#         nan        nan 0.8159     0.86375   ]
#   warnings.warn(
# --------------DECISION TREE CLASSIFIER with Bagging On MNIST----------------------
# Accuracy: 0.9086
# ---------------------------------------------------------

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint


#chosing the hyper-parameters which were chosen as the best on average for previous RandomForestClassifier Model

tree_model = RandomForestClassifier(verbose=0, random_state=0)

params = {
    'n_estimators': randint(60, 200),       
    'max_depth': randint(3, 10),                     
    'min_samples_split': randint(2, 10),     
    'min_samples_leaf': randint(1, 10),      
    'max_features': ['sqrt', 'log2']  
}


rand_s = RandomizedSearchCV(
    estimator=tree_model, 
    param_distributions=params, 
    n_iter=100,     
    cv=5,
    verbose=3,                    
    random_state=0
)

rand_s.fit(X_train, y_train)

best_model = rand_s.best_estimator_
test_score = best_model.score(X_test, y_test)


print("\n\n--------------RANDOM FOREST CLASSIFIER On MNIST----------------------")
print(f"Accuracy: {test_score}")
print("---------------------------------------------------------\n")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END max_depth=7, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators
_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=144;, score=0.924 total time=  14.3s
# [CV 2/5] END max_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=144;, score=0.922 total time=  14.2s
# [CV 3/5] END max_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=144;, score=0.916 total time=  14.2s
# [CV 4/5] END max_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=144;, score=0.919 total time=  14.3s
# [CV 5/5] END max_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=144;, score=0.930 total time=  14.4s
# [CV 1/5] END max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=144;, score=0.879 total time=   3.9s
# [CV 2/5] END max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=144;, score=0.870 total time=   3.9s
# [CV 3/5] END max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=144;, score=0.873 total time=   3.9s
# [CV 4/5] END max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=144;, score=0.878 total time=   3.9s
# [CV 5/5] END max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=144;, score=0.893 total time=   3.9s
#
#
# --------------RANDOM FOREST CLASSIFIER On MNIST----------------------
# Accuracy: 0.9389
# ---------------------------------------------------------

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

#chosing the hyper-parameters which were chosen as the best on average for previous GradientBoostingClassifier Model

tree_model = GradientBoostingClassifier(loss='log_loss', criterion='friedman_mse', verbose=0)



params = {
    'n_estimators': randint(50, 200),
    'learning_rate': uniform(0.01, 0.1),
    'max_depth': randint(3, 10),
    'subsample': uniform(0.5, 1.0),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 10),
    'max_features': ['sqrt', 'log2']
}

rand_s = RandomizedSearchCV(
    estimator=tree_model, 
    param_distributions=params, 
    n_iter=50, 
    cv=5, 
    verbose=3,  
    random_state=0
)


rand_s.fit(X_train, y_train)

best_model = rand_s.best_estimator_
test_score = best_model.score(X_test, y_test)

print("\n\n--------------Gradient Boosting CLASSIFIER On MNIST----------------------")
print(f"Accuracy: {test_score}")
print("---------------------------------------------------------\n")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END learning_rate=0.06488135039273248, max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=153, subsample=0.9236547993389047;, score=0.974 total time= 6.7min
# [CV 2/5] END learning_rate=0.06488135039273248, max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=153, subsample=0.9236547993389047;, score=0.972 total time= 3.8min
# [CV 3/5] END learning_rate=0.06488135039273248, max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=153, subsample=0.9236547993389047;, score=0.970 total time= 3.8min
# [CV 4/5] END learning_rate=0.06488135039273248, max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=153, subsample=0.9236547993389047;, score=0.969 total time= 3.8min
# [CV 5/5] END learning_rate=0.06488135039273248, max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=153, subsample=0.9236547993389047;, score=0.975 total time= 3.8min
# [CV 1/5] END learning_rate=0.0745894113066656, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=138, subsample=0.7726562945801132;, score=0.968 total time= 1.1min
# [CV 2/5] END learning_rate=0.0745894113066656, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=138, subsample=0.7726562945801132;, score=0.966 total time= 1.1min
# [CV 3/5] END learning_rate=0.0745894113066656, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=138, subsample=0.7726562945801132;, score=0.965 total time= 1.1min
# [CV 4/5] END learning_rate=0.0745894113066656, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=138, subsample=0.7726562945801132;, score=0.964 total time= 1.1min
# [CV 5/5] END learning_rate=0.0745894113066656, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=138, subsample=0.7726562945801132;, score=0.971 total time= 1.1min
# [CV 1/5] END learning_rate=0.05776651173213499, max_depth=9, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=75, subsample=0.5710360581978869;, score=0.966 total time= 1.6min
# [CV 2/5] END learning_rate=0.05776651173213499, max_depth=9, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=75, subsample=0.5710360581978869;, score=0.963 total time= 1.6min
# [CV 3/5] END learning_rate=0.05776651173213499, max_depth=9, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=75, subsample=0.5710360581978869;, score=0.961 total time= 1.6min
# [CV 4/5] END learning_rate=0.05776651173213499, max_depth=9, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators
max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=118, subsample=1.4589492686245205;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.04637107709426226, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=118, subsample=1.4589492686245205;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.04637107709426226, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=118, subsample=1.4589492686245205;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.04637107709426226, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=118, subsample=1.4589492686245205;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.04637107709426226, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=118, subsample=1.4589492686245205;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.07527903170054909, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=128, subsample=0.9663107728563063;, score=0.967 total time= 1.2min
# [CV 2/5] END learning_rate=0.07527903170054909, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=128, subsample=0.9663107728563063;, score=0.967 total time= 1.2min
# [CV 3/5] END learning_rate=0.07527903170054909, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=128, subsample=0.9663107728563063;, score=0.965 total time= 1.2min
# [CV 4/5] END learning_rate=0.07527903170054909, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=128, subsample=0.9663107728563063;, score=0.961 total time= 1.2min
# [CV 5/5] END learning_rate=0.07527903170054909, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=128, subsample=0.9663107728563063;, score=0.970 total time= 1.2min
# [CV 1/5] END learning_rate=0.034442559200160275, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=99, subsample=1.278345482025909;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.034442559200160275, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=99, subsample=1.278345482025909;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.034442559200160275, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=99, subsample=1.278345482025909;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.034442559200160275, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=99, subsample=1.278345482025909;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.034442559200160275, max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=99, subsample=1.278345482025909;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.10495710534507421, max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=86, subsample=0.5960984078939631;, score=0.968 total time= 1.5min
# [CV 2/5] END learning_rate=0.10495710534507421, max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=86, subsample=0.5960984078939631;, score=0.968 total time= 1.5min
# [CV 3/5] END learning_rate=0.10495710534507421, max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=86, subsample=0.5960984078939631;, score=0.967 total time= 1.5min
# [CV 4/5] END learning_rate=0.10495710534507421, max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=86, subsample=0.5960984078939631;, score=0.964 total time= 1.5min
# [CV 5/5] END learning_rate=0.10495710534507421, max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=86, subsample=0.5960984078939631;, score=0.970 total time= 1.6min
# [CV 1/5] END learning_rate=0.10764594650133957, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=199, subsample=1.2392635793983016;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.10764594650133957, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=199, subsample=1.2392635793983016;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.10764594650133957, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=199, subsample=1.2392635793983016;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.10764594650133957, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=199, subsample=1.2392635793983016;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.10764594650133957, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=199, subsample=1.2392635793983016;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.013918779225432068, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=180, subsample=1.1886611828057703;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.013918779225432068, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=180, subsample=1.1886611828057703;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.013918779225432068, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=180, subsample=1.1886611828057703;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.013918779225432068, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=180, subsample=1.1886611828057703;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.013918779225432068, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=180, subsample=1.1886611828057703;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.09804758892525954, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=198, subsample=0.7653894909394454;, score=0.974 total time= 2.8min
# [CV 2/5] END learning_rate=0.09804758892525954, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=198, subsample=0.7653894909394454;, score=0.975 total time= 2.8min
# [CV 3/5] END learning_rate=0.09804758892525954, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=198, subsample=0.7653894909394454;, score=0.970 total time= 2.8min
# [CV 4/5] END learning_rate=0.09804758892525954, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=198, subsample=0.7653894909394454;, score=0.971 total time= 2.8min
# [CV 5/5] END learning_rate=0.09804758892525954, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=198, subsample=0.7653894909394454;, score=0.975 total time= 2.8min
# [CV 1/5] END learning_rate=0.062324805346669974, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=60, subsample=0.7777185612810324;, score=0.926 total time=  31.1s
# [CV 2/5] END learning_rate=0.062324805346669974, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=60, subsample=0.7777185612810324;, score=0.924 total time=  31.0s
# [CV 3/5] END learning_rate=0.062324805346669974, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=60, subsample=0.7777185612810324;, score=0.921 total time=  31.0s
# [CV 4/5] END learning_rate=0.062324805346669974, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=60, subsample=0.7777185612810324;, score=0.924 total time=  30.9s
# [CV 5/5] END learning_rate=0.062324805346669974, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=60, subsample=0.7777185612810324;, score=0.933 total time=  30.9s
# [CV 1/5] END learning_rate=0.010935670485653262, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=178, subsample=0.7647301642834496;, score=0.919 total time=  51.3s
# [CV 2/5] END learning_rate=0.010935670485653262, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=178, subsample=0.7647301642834496;, score=0.919 total time=  51.5s
# [CV 3/5] END learning_rate=0.010935670485653262, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=178, subsample=0.7647301642834496;, score=0.913 total time=  51.9s
# [CV 4/5] END learning_rate=0.010935670485653262, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=178, subsample=0.7647301642834496;, score=0.914 total time=  51.5s
# [CV 5/5] END learning_rate=0.010935670485653262, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=178, subsample=0.7647301642834496;, score=0.924 total time=  51.5s
# [CV 1/5] END learning_rate=0.04978207527586291, max_depth=6, max_features=sqrt, min_samples_leaf=9, min_samples_split=7, n_estimators=80, subsample=0.6464417627291122;, score=0.956 total time=  58.7s
# [CV 2/5] END learning_rate=0.04978207527586291, max_depth=6, max_features=sqrt, min_samples_leaf=9, min_samples_split=7, n_estimators=80, subsample=0.6464417627291122;, score=0.953 total time=  58.9s
# [CV 3/5] END learning_rate=0.04978207527586291, max_depth=6, max_features=sqrt, min_samples_leaf=9, min_samples_split=7, n_estimators=80, subsample=0.6464417627291122;, score=0.951 total time=  58.7s
# [CV 4/5] END learning_rate=0.04978207527586291, max_depth=6, max_features=sqrt, min_samples_leaf=9, min_samples_split=7, n_estimators=80, subsample=0.6464417627291122;, score=0.950 total time=  58.6s
# [CV 5/5] END learning_rate=0.04978207527586291, max_depth=6, max_features=sqrt, min_samples_leaf=9, min_samples_split=7, n_estimators=80, subsample=0.6464417627291122;, score=0.957 total time=  58.7s
# [CV 1/5] END learning_rate=0.06696184059233067, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=122, subsample=1.0761573344178368;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.06696184059233067, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=122, subsample=1.0761573344178368;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.06696184059233067, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=122, subsample=1.0761573344178368;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.06696184059233067, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=122, subsample=1.0761573344178368;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.06696184059233067, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=122, subsample=1.0761573344178368;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.0692041931271839, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=111, subsample=0.9471253786176274;, score=0.958 total time= 1.4min
# [CV 2/5] END learning_rate=0.0692041931271839, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=111, subsample=0.9471253786176274;, score=0.958 total time= 1.4min
# [CV 3/5] END learning_rate=0.0692041931271839, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=111, subsample=0.9471253786176274;, score=0.956 total time= 1.4min
# [CV 4/5] END learning_rate=0.0692041931271839, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=111, subsample=0.9471253786176274;, score=0.956 total time= 1.4min
# [CV 5/5] END learning_rate=0.0692041931271839, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=111, subsample=0.9471253786176274;, score=0.963 total time= 1.4min
# [CV 1/5] END learning_rate=0.09464086724711278, max_depth=8, max_features=log2, min_samples_leaf=7, min_samples_split=7, n_estimators=171, subsample=0.8965057408469846;, score=0.974 total time= 1.9min
# [CV 2/5] END learning_rate=0.09464086724711278, max_depth=8, max_features=log2, min_samples_leaf=7, min_samples_split=7, n_estimators=171, subsample=0.8965057408469846;, score=0.972 total time= 1.9min
# [CV 3/5] END learning_rate=0.09464086724711278, max_depth=8, max_features=log2, min_samples_leaf=7, min_samples_split=7, n_estimators=171, subsample=0.8965057408469846;, score=0.970 total time= 2.0min
# [CV 4/5] END learning_rate=0.09464086724711278, max_depth=8, max_features=log2, min_samples_leaf=7, min_samples_split=7, n_estimators=171, subsample=0.8965057408469846;, score=0.968 total time= 1.9min
# [CV 5/5] END learning_rate=0.09464086724711278, max_depth=8, max_features=log2, min_samples_leaf=7, min_samples_split=7, n_estimators=171, subsample=0.8965057408469846;, score=0.974 total time= 1.9min
# [CV 1/5] END learning_rate=0.09811031971111615, max_depth=3, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=75, subsample=1.0884650850687494;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.09811031971111615, max_depth=3, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=75, subsample=1.0884650850687494;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.09811031971111615, max_depth=3, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=75, subsample=1.0884650850687494;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.09811031971111615, max_depth=3, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=75, subsample=1.0884650850687494;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.09811031971111615, max_depth=3, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=75, subsample=1.0884650850687494;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.07596684120694128, max_depth=8, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=154, subsample=0.9238550485581797;, score=0.973 total time= 1.8min
# [CV 2/5] END learning_rate=0.07596684120694128, max_depth=8, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=154, subsample=0.9238550485581797;, score=0.971 total time= 1.8min
# [CV 3/5] END learning_rate=0.07596684120694128, max_depth=8, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=154, subsample=0.9238550485581797;, score=0.967 total time= 1.8min
# [CV 4/5] END learning_rate=0.07596684120694128, max_depth=8, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=154, subsample=0.9238550485581797;, score=0.967 total time= 1.8min
# [CV 5/5] END learning_rate=0.07596684120694128, max_depth=8, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=154, subsample=0.9238550485581797;, score=0.972 total time= 1.8min
# [CV 1/5] END learning_rate=0.07063932141279243, max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=63, subsample=0.7879910043632805;, score=0.932 total time=  32.8s
# [CV 2/5] END learning_rate=0.07063932141279243, max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=63, subsample=0.7879910043632805;, score=0.928 total time=  32.8s
# [CV 3/5] END learning_rate=0.07063932141279243, max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=63, subsample=0.7879910043632805;, score=0.928 total time=  32.7s
# [CV 4/5] END learning_rate=0.07063932141279243, max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=63, subsample=0.7879910043632805;, score=0.929 total time=  32.7s
# [CV 5/5] END learning_rate=0.07063932141279243, max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=63, subsample=0.7879910043632805;, score=0.938 total time=  32.9s
# [CV 1/5] END learning_rate=0.04834622250349479, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=61, subsample=0.5923738894608982;, score=0.919 total time=  25.9s
# [CV 2/5] END learning_rate=0.04834622250349479, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=61, subsample=0.5923738894608982;, score=0.917 total time=  25.9s
# [CV 3/5] END learning_rate=0.04834622250349479, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=61, subsample=0.5923738894608982;, score=0.914 total time=  26.0s
# [CV 4/5] END learning_rate=0.04834622250349479, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=61, subsample=0.5923738894608982;, score=0.913 total time=  25.8s
# [CV 5/5] END learning_rate=0.04834622250349479, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=61, subsample=0.5923738894608982;, score=0.923 total time=  26.1s
# [CV 1/5] END learning_rate=0.045404666208381024, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=175, subsample=0.8209972413734975;, score=0.944 total time=  40.5s
# [CV 2/5] END learning_rate=0.045404666208381024, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=175, subsample=0.8209972413734975;, score=0.938 total time=  40.4s
# [CV 3/5] END learning_rate=0.045404666208381024, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=175, subsample=0.8209972413734975;, score=0.934 total time=  40.5s
# [CV 4/5] END learning_rate=0.045404666208381024, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=175, subsample=0.8209972413734975;, score=0.937 total time=  40.6s
# [CV 5/5] END learning_rate=0.045404666208381024, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=175, subsample=0.8209972413734975;, score=0.946 total time=  40.4s
# [CV 1/5] END learning_rate=0.03212626851837828, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=93, subsample=0.6002268873123011;, score=0.951 total time= 1.1min
# [CV 2/5] END learning_rate=0.03212626851837828, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=93, subsample=0.6002268873123011;, score=0.947 total time= 1.1min
# [CV 3/5] END learning_rate=0.03212626851837828, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=93, subsample=0.6002268873123011;, score=0.944 total time= 1.1min
# [CV 4/5] END learning_rate=0.03212626851837828, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=93, subsample=0.6002268873123011;, score=0.946 total time= 1.1min
# [CV 5/5] END learning_rate=0.03212626851837828, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=93, subsample=0.6002268873123011;, score=0.952 total time= 1.1min
# [CV 1/5] END learning_rate=0.10194826137446736, max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=161, subsample=0.5375593838281403;, score=0.966 total time= 1.3min
# [CV 2/5] END learning_rate=0.10194826137446736, max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=161, subsample=0.5375593838281403;, score=0.967 total time= 1.3min
# [CV 3/5] END learning_rate=0.10194826137446736, max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=161, subsample=0.5375593838281403;, score=0.962 total time= 1.3min
# [CV 4/5] END learning_rate=0.10194826137446736, max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=161, subsample=0.5375593838281403;, score=0.965 total time= 1.3min
# [CV 5/5] END learning_rate=0.10194826137446736, max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=161, subsample=0.5375593838281403;, score=0.969 total time= 1.3min
# [CV 1/5] END learning_rate=0.060831544857889094, max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=198, subsample=0.9113967237554546;, score=0.950 total time=  47.7s
# [CV 2/5] END learning_rate=0.060831544857889094, max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=198, subsample=0.9113967237554546;, score=0.951 total time=  47.6s
# [CV 3/5] END learning_rate=0.060831544857889094, max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=198, subsample=0.9113967237554546;, score=0.949 total time=  48.3s
# [CV 4/5] END learning_rate=0.060831544857889094, max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=198, subsample=0.9113967237554546;, score=0.947 total time=  47.9s
# [CV 5/5] END learning_rate=0.060831544857889094, max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=198, subsample=0.9113967237554546;, score=0.956 total time=  48.0s
# [CV 1/5] END learning_rate=0.02399725854932017, max_depth=4, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=96, subsample=1.222055599470348;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.02399725854932017, max_depth=4, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=96, subsample=1.222055599470348;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.02399725854932017, max_depth=4, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=96, subsample=1.222055599470348;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.02399725854932017, max_depth=4, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=96, subsample=1.222055599470348;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.02399725854932017, max_depth=4, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=96, subsample=1.222055599470348;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.09663823259286292, max_depth=4, max_features=sqrt, min_samples_leaf=8, min_samples_split=9, n_estimators=111, subsample=1.229990562424058;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.09663823259286292, max_depth=4, max_features=sqrt, min_samples_leaf=8, min_samples_split=9, n_estimators=111, subsample=1.229990562424058;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.09663823259286292, max_depth=4, max_features=sqrt, min_samples_leaf=8, min_samples_split=9, n_estimators=111, subsample=1.229990562424058;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.09663823259286292, max_depth=4, max_features=sqrt, min_samples_leaf=8, min_samples_split=9, n_estimators=111, subsample=1.229990562424058;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.09663823259286292, max_depth=4, max_features=sqrt, min_samples_leaf=8, min_samples_split=9, n_estimators=111, subsample=1.229990562424058;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.02716296772614405, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=86, subsample=0.6709865986831315;, score=0.933 total time=  51.7s
# [CV 2/5] END learning_rate=0.02716296772614405, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=86, subsample=0.6709865986831315;, score=0.931 total time=  51.4s
# [CV 3/5] END learning_rate=0.02716296772614405, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=86, subsample=0.6709865986831315;, score=0.924 total time=  52.0s
# [CV 4/5] END learning_rate=0.02716296772614405, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=86, subsample=0.6709865986831315;, score=0.927 total time=  51.6s
# [CV 5/5] END learning_rate=0.02716296772614405, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=86, subsample=0.6709865986831315;, score=0.936 total time=  51.8s
# [CV 1/5] END learning_rate=0.0563450977384483, max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=186, subsample=1.096655406295053;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.0563450977384483, max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=186, subsample=1.096655406295053;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.0563450977384483, max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=186, subsample=1.096655406295053;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.0563450977384483, max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=186, subsample=1.096655406295053;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0
max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=122, subsample=0.7735420348156358;, score=0.961 total time= 1.9min
# [CV 4/5] END learning_rate=0.042468297206646535, max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=122, subsample=0.7735420348156358;, score=0.961 total time= 1.9min
# [CV 5/5] END learning_rate=0.042468297206646535, max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=122, subsample=0.7735420348156358;, score=0.969 total time= 1.9min
# [CV 1/5] END learning_rate=0.08980468339125637, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=114, subsample=0.9834086165987527;, score=0.956 total time= 1.2min
# [CV 2/5] END learning_rate=0.08980468339125637, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=114, subsample=0.9834086165987527;, score=0.953 total time= 1.2min
# [CV 3/5] END learning_rate=0.08980468339125637, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=114, subsample=0.9834086165987527;, score=0.952 total time= 1.2min
# [CV 4/5] END learning_rate=0.08980468339125637, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=114, subsample=0.9834086165987527;, score=0.949 total time= 1.2min
# [CV 5/5] END learning_rate=0.08980468339125637, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=114, subsample=0.9834086165987527;, score=0.958 total time= 1.2min
# [CV 1/5] END learning_rate=0.08887394275320365, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=70, subsample=1.4574508556589536;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.08887394275320365, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=70, subsample=1.4574508556589536;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.08887394275320365, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=70, subsample=1.4574508556589536;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.08887394275320365, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=70, subsample=1.4574508556589536;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.08887394275320365, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=70, subsample=1.4574508556589536;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.05717515708928012, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=111, subsample=0.8741699803342255;, score=0.948 total time=  34.5s
# [CV 2/5] END learning_rate=0.05717515708928012, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=111, subsample=0.8741699803342255;, score=0.946 total time=  34.7s
# [CV 3/5] END learning_rate=0.05717515708928012, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=111, subsample=0.8741699803342255;, score=0.943 total time=  34.7s
# [CV 4/5] END learning_rate=0.05717515708928012, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=111, subsample=0.8741699803342255;, score=0.942 total time=  34.7s
# [CV 5/5] END learning_rate=0.05717515708928012, max_depth=5, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=111, subsample=0.8741699803342255;, score=0.951 total time=  34.4s
# [CV 1/5] END learning_rate=0.05635754243648108, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=142, subsample=1.174847345928692;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.05635754243648108, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=142, subsample=1.174847345928692;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.05635754243648108, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=142, subsample=1.174847345928692;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.05635754243648108, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=142, subsample=1.174847345928692;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.05635754243648108, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=142, subsample=1.174847345928692;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.0376893750817091, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=155, subsample=1.3404285325354324;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.0376893750817091, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=155, subsample=1.3404285325354324;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.0376893750817091, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=155, subsample=1.3404285325354324;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.0376893750817091, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=155, subsample=1.3404285325354324;, score=nan total time=   0.0s
# ...
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.0884650850687494 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.222055599470348 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.229990562424058 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.096655406295053 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.4923963988886326 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.2301220295167696 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.4443723899839336 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.1176579160958802 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.1070450611164517 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.145784598501899 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.4574508556589536 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.174847345928692 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.3404285325354324 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.2469942401995033 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.0844760689557689 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\vigha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.97185    0.96673333 0.96386667        nan        nan 0.9513
#  0.91965    0.95776667 0.97278333        nan 0.96603333        nan
#  0.96726667        nan        nan 0.97308333 0.92566667 0.918
#  0.95321667        nan 0.95808333 0.97138333        nan 0.97008333
#  0.93115    0.91705    0.93985    0.94806667 0.96591667 0.95065
#         nan        nan 0.93028333        nan        nan        nan
#         nan 0.94755           nan        nan 0.95011667        nan
#  0.96386667 0.95363333        nan 0.94588333        nan        nan
#         nan        nan]
#   warnings.warn(
# --------------Gradient Boosting CLASSIFIER On MNIST----------------------
# Accuracy: 0.9764
# ---------------------------------------------------------
